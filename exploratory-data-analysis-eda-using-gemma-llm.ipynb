# %% [markdown]
# <a href="https://www.kaggle.com/code/vinit0714/exploratory-data-analysis-eda-using-gemma-llm?scriptVersionId=165136891" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Gemma LLM Notebook: Exploratory Data Analysis (EDA) Tutorial
#
# In this notebook, we will demonstrate how to leverage Gemma Large Language Model (LLM) to perform Exploratory Data Analysis (EDA). Exploratory Data Analysis is a fundamental step in any data science project, allowing us to understand the underlying patterns, distributions, and relationships within our dataset.
#
# By harnessing the power of Gemma LLM, we aim to create a comprehensive tutorial that covers the basics of EDA, providing insights into how to effectively explore and visualize data to extract meaningful information.
#
# Our tutorial will focus on explaining key concepts and techniques used in EDA, such as data preprocessing, descriptive statistics, data visualization, and pattern identification. We will also showcase practical examples and code snippets using Gemma LLM to perform EDA tasks on real-world datasets.
#
# Through this notebook, readers will learn how to use Gemma LLM as a valuable tool for understanding and analyzing datasets, gaining insights that can inform decision-making and drive data-driven solutions.

# %%
import os

os.environ["KERAS_BACKEND"] = "torch"  # Or "jax" or "tensorflow".

# %% [markdown]
# ## Import Libraries
# Import necessary libraries

# %%
import keras
import keras_nlp
import numpy as np
# Out:
# 2024-03-02 13:50:19.089095: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-02 13:50:19.089202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-02 13:50:19.245125: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Initialize Gemma model
#
# In this notebook, we'll be utilizing the Gemma Language Model version gemma_instruct_2b_en. This specific model, gemma_instruct_2b_en, is designed to assist with various natural language processing tasks, including text generation and understanding.
#
# You can find more detailed information about this Gemma model by visiting the following link: [gemma_instruct_2b_en](https://www.kaggle.com/models/google/gemma/frameworks/keras/variations/gemma_2b_en)

# %%
gemma_lm = keras_nlp.models.GemmaCausalLM.from_preset("gemma_instruct_2b_en")

gemma_lm.generate("Hello, I am", max_length=30)
# Out:
# Attaching 'config.json' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Kaggle notebook...
# Attaching 'config.json' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Kaggle notebook...
# Attaching 'model.weights.h5' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Kaggle notebook...
# Attaching 'tokenizer.json' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Kaggle notebook...
# Attaching 'assets/tokenizer/vocabulary.spm' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Kaggle notebook...
# normalizer.cc(51) LOG(INFO) precompiled_charsmap is empty. use identity normalization.
# 'Hello, I am looking for a way to improve my understanding of a specific topic. I have been considering using flashcards, but I am not sure'

# %% [markdown]
# ## Use Gemma language model to explain Exploratory Data Analysis (EDA)
# In this part, we'll use Gemma to help explain Exploratory Data Analysis (EDA). EDA is like looking at a map before going on a trip—it helps us understand our data better before we start doing anything fancy with it.
#
# With Gemma's help, we'll make sure to keep things simple and easy to understand.

# %%
prompt = "Exploratory Data Analysis (EDA)"
explanation = gemma_lm.generate(prompt, max_length=400)

print(explanation)
# Out:
# Exploratory Data Analysis (EDA) is a crucial step in data science projects. EDA helps identify patterns, trends, and relationships within the data, leading to better data-driven decisions.
#
# **Here's how EDA can benefit data science projects:**
#
# * **Identify patterns and trends:** EDA helps identify patterns and trends in the data, which can be used to make predictions and insights.
# * **Discover relationships between variables:** EDA can help discover relationships between variables, which can lead to the development of new insights and solutions.
# * **Clean and prepare data for modeling:** EDA can be used to clean and prepare data for modeling, which can improve the accuracy and performance of machine learning models.
# * **Generate insights:** EDA can generate insights and knowledge from the data, which can be used to improve decision-making and problem-solving.
#
# **Here are some common EDA techniques:**
#
# ...

# %% [markdown]
# ## Generate Example Code for Exploratory Data Analysis (EDA) with Gemma
# In this section, we'll utilize Gemma to generate example code for performing Exploratory Data Analysis (EDA). EDA is all about understanding our data before we start digging deeper into it.
#
# With Gemma's assistance, we'll create some code examples that demonstrate common EDA tasks.

# %%
prompt = "Generate example code for performing Exploratory Data Analysis (EDA)."

eda_code = gemma_lm.generate(prompt, max_length=2000)
print(eda_code)
# Out:
# Generate example code for performing Exploratory Data Analysis (EDA).
#
# **Step 1: Load and Explore the Data**
#
# ```python
# import pandas as pd
#
# # Load the data from a CSV file
# data = pd.read_csv("data.csv")
#
# # Print the first 5 rows of the data
# print(data.head())
#
# # Explore the data by looking at the data types, column names, and data values
# print(data.dtypes)
# print(data.columns)
# print(data.values)
# ```
#
# **Step 2: Data Cleaning and Preprocessing**
#
# ```python
# # Drop rows with missing values
# data.dropna(inplace=True, subset="index")
#
# # Convert categorical variables to numerical variables
# data["category_column"] = data["category_column"].astype(int)
#
# # Normalize numerical variables
# data["numerical_column"] = (data["numerical_column"] - mean(data["numerical_column"])) / standard_deviation(data["numerical_column"])
# ```
#
# **Step 3: Descriptive Statistics and Data Visualization**
#
# ```python
# ...

# %% [markdown]
# ## Applying Gemma-Generated Code to Dataset Exploration
#
# Now, let's put Gemma's example code to work on a dataset for exploration. Gemma has provided us with code snippets that demonstrate common Exploratory Data Analysis (EDA) tasks. We'll use these snippets to gain insights into our dataset and understand its characteristics better and leveraging Gemma's expertise to explore our dataset efficiently.

# %% [markdown]
# ### Load and Explore the Data
# We'll start by loading our dataset and exploring its contents. Understanding the structure and characteristics of our data is crucial before we proceed with any analysis.

# %%
import pandas as pd

# %%
data = pd.read_csv("/kaggle/input/fast-food-sales-report/Balaji Fast Food Sales.csv")

# %%
data.head(5)
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
print(data.dtypes)
# Out:
# order_id               int64
# date                  object
# item_name             object
# item_type             object
# item_price             int64
# quantity               int64
# transaction_amount     int64
# transaction_type      object
# received_by           object
# time_of_sale          object
# dtype: object

# %%
print(data.columns)
# Out:
# Index(['order_id', 'date', 'item_name', 'item_type', 'item_price', 'quantity',
#        'transaction_amount', 'transaction_type', 'received_by',
#        'time_of_sale'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            1000 non-null   int64
#  1   date                1000 non-null   object
#  2   item_name           1000 non-null   object
#  3   item_type           1000 non-null   object
#  4   item_price          1000 non-null   int64
#  5   quantity            1000 non-null   int64
#  6   transaction_amount  1000 non-null   int64
#  7   transaction_type    893 non-null    object
#  8   received_by         1000 non-null   object
#  9   time_of_sale        1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.2+ KB

# %%
print(data.values)
# Out:
# [[1 '07-03-2022' 'Aalopuri' ... nan 'Mr.' 'Night']
#  [2 '8/23/2022' 'Vadapav' ... 'Cash' 'Mr.' 'Afternoon']
#  [3 '11/20/2022' 'Vadapav' ... 'Cash' 'Mr.' 'Afternoon']
#  ...
#  [998 '1/26/2023' 'Sandwich' ... nan 'Mr.' 'Evening']
#  [999 '8/27/2022' 'Panipuri' ... nan 'Mrs.' 'Afternoon']
#  [1000 '5/29/2022' 'Aalopuri' ... 'Online' 'Mrs.' 'Midnight']]

# %% [markdown]
# ### Data Cleaning and Preprocessing
# Tasks in this section may include handling missing values, converting data types, and normalizing numerical variables.
#
# Data Cleaning and Preprocessing are critical steps in the Exploratory Data Analysis (EDA) process. In this section, we'll also use Gemma's language capabilities to shed light on the significance of these steps.

# %%
prompt = "why Data Cleaning and Preprocessing is important in EDA??"

explain = gemma_lm.generate(prompt, max_length=500)
print(explain)
# Out:
# why Data Cleaning and Preprocessing is important in EDA??
#
# **Data cleaning and preprocessing are crucial steps in exploratory data analysis (EDA) for several reasons:**
#
# **1. Identifying Data Discrepancies:**
# - Missing values, outliers, and inconsistent formatting can lead to significant biases and inaccurate results.
# - Data cleaning and preprocessing step identify and address these issues, ensuring the integrity and accuracy of the data.
#
# **2. Detecting Data Relationships:**
# - By identifying patterns and relationships between variables, data cleaning and preprocessing help uncover hidden insights.
# - This knowledge can guide further analysis and model development.
#
# **3. Improving Data Quality:**
# - Data cleaning and preprocessing ensure that data is consistent, complete, and free from errors.
# - This improves the reliability and validity of the results obtained from EDA.
#
# **4. Enhancing Data Analysis Efficiency:**
# ...

# %% [markdown]
# #### Taking help of Gemma to standardize date formats in dataset
# utilizing Gemma to efficiently tackle this data preprocessing task and achieve uniformity in the date format within our dataset

# %%
prompt = """I am working on a python notebook and in my dataset date column i have some dataset different format like 07-03-2022 and 8/23/2022.
I want to replace / with - in my date dataset and so convert all dataset to format like 07-03-2022"""

solve_problem = gemma_lm.generate(prompt, max_length=500)
print(solve_problem)
# Out:
# I am working on a python notebook and in my dataset date column i have some dataset different format like 07-03-2022 and 8/23/2022.
# I want to replace / with - in my date dataset and so convert all dataset to format like 07-03-2022.
#
# Here is my code:
#
# ```python
# import pandas as pd
#
# # Load the dataset
# df = pd.read_csv("your_file.csv")
#
# # Replace / with - in the date column
# df["date"] = df["date"].str.replace("/", "-")
#
# # Convert the date column to the desired format
# df["date"] = pd.to_datetime(df["date"], format="%d-%m-%Y")
#
# # Print the resulting dataframe
# print(df)
# ```
#
# **Output:**
#
# ```
#            date
# 0  07-03-2022
# 1  08-23-2022
# ```
#
# **Explanation:**
#
# 1. `str.replace("/", "-")` replaces all occurrences of `/` with `-` in the `date` column.
# 2. `pd.to_datetime()` converts the `date` column to a datetime object, with the format `"%d-%m-%Y"`. This format is recognized by pandas as the date and time in that order.
#
# **Note:**
#
# ...

# %%
data['date'].str.replace('/', '-')
data['date']=pd.to_datetime(data['date'],format="mixed")
data.head()
# Out:
#    order_id       date        item_name  item_type  item_price  quantity  \
# 0         1 2022-07-03         Aalopuri   Fastfood          20        13
# 1         2 2022-08-23          Vadapav   Fastfood          20        15
# 2         3 2022-11-20          Vadapav   Fastfood          20         1
# 3         4 2023-02-03  Sugarcane juice  Beverages          25         6
# 4         5 2022-10-02  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
data.isna().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (893, 10)

# %%
data
# Out:
#      order_id       date        item_name  item_type  item_price  quantity  \
# 1           2 2022-08-23          Vadapav   Fastfood          20        15
# 2           3 2022-11-20          Vadapav   Fastfood          20         1
# 3           4 2023-02-03  Sugarcane juice  Beverages          25         6
# 4           5 2022-10-02  Sugarcane juice  Beverages          25         8
# 5           6 2022-11-14          Vadapav   Fastfood          20        10
# ..        ...        ...              ...        ...         ...       ...
# 991       992 2022-10-21         Sandwich   Fastfood          60         5
# 992       993 2022-07-17          Frankie   Fastfood          50         3
# 993       994 2022-11-01         Panipuri   Fastfood          20         2
# 994       995 2022-06-18  Sugarcane juice  Beverages          25         1
# 999      1000 2022-05-29         Aalopuri   Fastfood          20         3
#
#      transaction_amount transaction_type received_by time_of_sale
# ...

# %%
data.dtypes
# Out:
# order_id                       int64
# date                  datetime64[ns]
# item_name                     object
# item_type                     object
# item_price                     int64
# quantity                       int64
# transaction_amount             int64
# transaction_type              object
# received_by                   object
# time_of_sale                  object
# dtype: object

# %% [markdown]
# ### Utilizing Gemma for Dataset Analysis and Factor Generation for EDA
# In this section, we'll employ Gemma to analyze our dataset and generate factors that are crucial for performing Exploratory Data Analysis (EDA). Gemma's language capabilities will assist us in identifying key variables and factors that should be considered during the EDA process.
#
# By leveraging Gemma's insights, we'll be able to determine which aspects of our dataset are most relevant for exploration and visualization, ultimately facilitating a more effective EDA workflow.

# %%
prompt = f"""I have fast food sales dataset with columns and dataset as follows:
{data.dtypes}
so on what factors from above dataset my EDA should be performed for visualising data?? Explain the reasoning behind selection of those factors and what visualisation types i should use"""
 

solve_problem = gemma_lm.generate(prompt, max_length=4000)
print(solve_problem)
# Out:
# I have fast food sales dataset with columns and dataset as follows:
# order_id                       int64
# date                  datetime64[ns]
# item_name                     object
# item_type                     object
# item_price                     int64
# quantity                       int64
# transaction_amount             int64
# transaction_type              object
# received_by                   object
# time_of_sale                  object
# dtype: object
# so on what factors from above dataset my EDA should be performed for visualising data?? Explain the reasoning behind selection of those factors and what visualisation types i should use for each factor.
#
# **Factors to consider for EDA:**
#
# * Order quantity
# * Item price
# * Transaction amount
# * Time of sale
#
# **Reasoning:**
#
# ...

# %% [markdown]
# ### Descriptive Statistics and Data Visualization
# In this section, we'll use descriptive statistics and data visualization techniques to gain a deeper understanding of our dataset. Descriptive statistics provide summaries of the main characteristics of the data, while data visualization helps us visualize patterns, trends, and relationships.
#
# Let's see how these techniques are useful in EDA with Gemma's assistance

# %%
prompt = "How Descriptive Statistics and Data Visualization is useful in EDA??"

explain = gemma_lm.generate(prompt, max_length=500)
print(explain)
# Out:
# How Descriptive Statistics and Data Visualization is useful in EDA??
#
# Descriptive statistics and data visualization are powerful tools that can be used to explore and understand data. By understanding the central tendency, dispersion, and relationships between variables, descriptive statistics can help identify patterns and trends in the data. Data visualization, on the other hand, can help to communicate these patterns and trends in a clear and concise way.
#
# **Descriptive statistics** can be used to:
#
# * **Identify the central tendency:** The mean, median, and mode are all measures of the central tendency that can be used to describe a dataset.
# * **Identify the dispersion:** The variance and standard deviation can be used to describe how spread out the data is.
# * **Identify relationships between variables:** Scatter plots and correlation coefficients can be used to identify relationships between variables.
#
# **Data visualization** can be used to:
#
# ...

# %%
display(data.describe())
# Out:
#           order_id                           date  item_price    quantity  \
# count   893.000000                            893  893.000000  893.000000
# mean    506.166853  2022-10-03 02:23:30.974243840   33.359462    8.100784
# min       2.000000            2022-04-01 00:00:00   20.000000    1.000000
# 25%     260.000000            2022-07-04 00:00:00   20.000000    4.000000
# 50%     510.000000            2022-10-07 00:00:00   25.000000    8.000000
# 75%     755.000000            2023-01-02 00:00:00   50.000000   12.000000
# max    1000.000000            2023-03-30 00:00:00   60.000000   15.000000
# std     287.605949                            NaN   15.000808    4.390283
#
#        transaction_amount
# count          893.000000
# mean           272.603583
# min             20.000000
# 25%            120.000000
# 50%            240.000000
# 75%            360.000000
# max            900.000000
# std            202.457635

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns

# %%
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month

# Group by year and month and sum the quantity
order_quantity_per_month = data.groupby(['year', 'month'])['quantity'].sum()

order_quantity_per_month.plot(kind='line', figsize=(12, 6), marker='o')

plt.title('Order Quantity Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Order Quantity')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='item_price', y='item_name', hue='item_type', data=data, palette='Set2', s=500)

# Set title and labels
plt.title('Item Price vs Item Name (Color Coded by Item Category)')
plt.xlabel('Item Price')
plt.ylabel('Item Name')

# Show legend
plt.legend(title='Item Type')

# Show plot
plt.tight_layout()
plt.show()

# %%
data['year_month'] = data['date'].dt.to_period('M')

# Group by year and month and sum transaction amounts
transaction_amount_per_month = data.groupby('year_month')['transaction_amount'].sum()

# Plot line chart for transaction amount over time
plt.figure(figsize=(12, 6))
transaction_amount_per_month.plot(kind='line', color='blue', marker='o')

plt.title('Transaction Amount Over Time (Monthly)')
plt.xlabel('Year-Month')
plt.ylabel('Transaction Amount')

plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
time_of_sale_per_month = data.groupby(['year_month', 'time_of_sale']).size().unstack(fill_value=0)

plt.figure(figsize=(12, 6))
time_of_sale_per_month.plot(kind='line', marker='o')

plt.title('Time of Sale Over Time (Monthly)')
plt.xlabel('Year-Month')
plt.ylabel('Count')

plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.legend(title='Time of Sale', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 6))
time_of_sale_per_month.plot(kind='area', stacked=False, color=['aqua', 'red', 'blue', 'orange', 'green'])

plt.title('Time of Sale Over Time (Monthly)')
plt.xlabel('Year-Month')
plt.ylabel('Count')

plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.legend(title='Time of Sale', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# With the help of visualization techniques, we can observe patterns and relationships in our data more effectively.
#
# - Order quantity: Utilize a line chart to visualize order quantity over time, presenting it as a time series.
# - Item price: Employ a scatter plot to display item price, with color coding based on item category to highlight differences between categories.
# - Transaction amount: Represent transaction amount using a line chart to depict its variation over time, capturing the temporal aspect of sales.
# - Time of sale: Use a line chart to visualize the time of sale over time, providing insights into any temporal patterns or trends in sales activity.

# %% [markdown]
# ### Identify Patterns and Relationships

# %%
item_type_count_per_month = data.groupby(['month', 'item_type']).size().unstack(fill_value=0)

# Plot the count of each item type per month as separate bars without stacking
item_type_count_per_month.plot(kind='bar', figsize=(12, 6), width=0.8)  # Adjust the width here

plt.title('Count of Each Item Type per Month')
plt.xlabel('Month')
plt.ylabel('Count')

# Adjust legend and axis labels
plt.legend(title='Item Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
cross_tab = pd.crosstab(index=[data['item_name'], data['item_type']], columns=[data['transaction_type'], data['received_by']])

print(cross_tab)
# Out:
# transaction_type          Cash      Online
# received_by                Mr. Mrs.    Mr. Mrs.
# item_name       item_type
# Aalopuri        Fastfood    38   28     28   25
# Cold coffee     Beverages   45   27     27   39
# Frankie         Fastfood    32   30     26   39
# Panipuri        Fastfood    32   38     37   28
# Sandwich        Fastfood    31   32     30   24
# Sugarcane juice Beverages   38   38     33   27
# Vadapav         Fastfood    35   32     27   27

# %% [markdown]
# #### Interpretation of Cross-Tabulation Analysis using Gemma
# Cross-tabulation analysis is a valuable technique for exploring relationships between categorical variables in a dataset. Gemma can assist in interpreting the results of cross-tabulation analysis, providing insights into the observed associations and patterns.
#
# let's how Gemma can help interpret cross-tabulation analysis:

# %%
prompt = f"""what does this cross-tabulation analysis say
{cross_tab}"""

solve_problem = gemma_lm.generate(prompt, max_length=1000)
print(solve_problem)
# Out:
# what does this cross-tabulation analysis say
# transaction_type          Cash      Online
# received_by                Mr. Mrs.    Mr. Mrs.
# item_name       item_type
# Aalopuri        Fastfood    38   28     28   25
# Cold coffee     Beverages   45   27     27   39
# Frankie         Fastfood    32   30     26   39
# Panipuri        Fastfood    32   38     37   28
# Sandwich        Fastfood    31   32     30   24
# Sugarcane juice Beverages   38   38     33   27
# Vadapav         Fastfood    35   32     27   27
#
# The cross-tabulation shows the number of transactions for each type of item sold, where the rows represent the different types of items and the columns represent the different transaction types.
#
# The results of the cross-tabulation indicate that:
#
# - Cash was used for 28 transactions, while Online was used for 27 transactions.
# - Fastfood was the most popular item, with 38 transactions using this method.
# ...

# %%
correlation_matrix = data[['item_price', 'transaction_amount']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
data['item_type'] = data['item_type'].astype('category').cat.codes
data['time_of_sale'] = data['time_of_sale'].astype('category').cat.codes
data['item_name'] = data['item_name'].astype('category').cat.codes
data['item_price'] = data['item_price'].astype('category').cat.codes

correlation_columns = ['item_type', 'item_price', 'time_of_sale', 'item_name']

correlation_matrix = data[correlation_columns].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
print(correlation_matrix)
# Out:
#               item_type  item_price  time_of_sale  item_name
# item_type      1.000000   -0.041517      0.036548   0.001895
# item_price    -0.041517    1.000000      0.021573  -0.070051
# time_of_sale   0.036548    0.021573      1.000000  -0.043025
# item_name      0.001895   -0.070051     -0.043025   1.000000

# %% [markdown]
# #### Interpretation of Correlation Matrix with Gemma
# A correlation matrix provides valuable insights into the relationships between numerical variables in a dataset. Gemma can assist in interpreting the correlation matrix, helping us understand the strength and direction of these relationships.
#
# let's see how Gemma can help interpret a correlation matrix:

# %%
prompt = f"""what does this Correlation Matrix say
{correlation_matrix}"""

solve_problem = gemma_lm.generate(prompt, max_length=1000)
print(solve_problem)
# Out:
# what does this Correlation Matrix say
#               item_type  item_price  time_of_sale  item_name
# item_type      1.000000   -0.041517      0.036548   0.001895
# item_price    -0.041517    1.000000      0.021573  -0.070051
# time_of_sale   0.036548    0.021573      1.000000  -0.043025
# item_name      0.001895   -0.070051     -0.043025   1.000000
#
# The correlation matrix shows the relationship between different items in the dataset.
#
# - **item_type** and **item_price** are negatively correlated, meaning that as item_type increases, item_price decreases.
# - **item_type** and **time_of_sale** are positively correlated, meaning that as item_type increases, time_of_sale decreases.
# - **item_price** and **time_of_sale** are negatively correlated, meaning that as item_price increases, time_of_sale decreases.
#
# ...

# %% [markdown]
# # Overview of the Notebook
#
# In this notebook, we embarked on an exploration of Exploratory Data Analysis (EDA) using the Gemma Language Model. We leveraged Gemma's capabilities to guide us through various aspects of EDA, from data cleaning and preprocessing to descriptive statistics, data visualization, and advanced analytical techniques.
#
# We also explained following topics using the gemma_instruct_2b_en model:
#
# - Introduction to EDA: Introduced the concept of Exploratory Data Analysis and its importance in the data science workflow.
#
# - Data Cleaning and Preprocessing: With Gemma's assistance, we cleaned and preprocessed our dataset to ensure its quality and consistency, preparing it for analysis.
#
# - Descriptive Statistics: Gemma helped us understand the distribution and characteristics of our data through descriptive statistics, such as mean, median, and standard deviation.
#
# - Data Visualization: We utilized Gemma's insights to create informative visualizations, including histograms, box plots, and scatter plots, to explore patterns and relationships within our dataset visually.
#
# - Cross-Tabulation Analysis: Gemma assisted us in interpreting cross-tabulation analysis, revealing associations between categorical variables in our dataset.
#
# - Correlation Matrix Interpretation: With Gemma's guidance, we delved into the interpretation of correlation matrices, uncovering relationships between numerical variables and their implications for analysis.

# %% [markdown]
# # Key Findings about Gemma from this Project
#
# Based on the utilization of Gemma in this project, we can draw several findings:
#
# 1. **Language Understanding:** Gemma exhibits a strong capability in understanding natural language queries and instructions related to data science tasks, including EDA.
#
# 2. **Task Assistance:** Gemma effectively assists in various stages of the data science workflow, from data cleaning and preprocessing to descriptive statistics, data visualization, and advanced analytical techniques like cross-tabulation analysis and correlation matrix interpretation.
#
# 3. **Insight Generation:** Gemma aids in generating insights from data through descriptive explanations, interpretation of analysis results, and recommendations for further exploration.
#
# 4. **User Guidance:** Gemma provides clear and concise guidance to users, helping them navigate complex data analysis tasks and understand the underlying concepts and methodologies involved.
#
# 5. **Efficiency:** Gemma enhances the efficiency of the data science process by automating repetitive tasks, providing quick responses to queries, and offering valuable suggestions for analysis.
#
# 6. **Knowledge Representation:** Gemma demonstrates a rich understanding of data science concepts, techniques, and best practices, enabling it to provide accurate and relevant assistance to users.
#
# The findings from this project underscore Gemma's pivotal role as an indispensable tool for data scientists throughout the data analysis journey. Gemma's comprehensive support spans every stage of the process, from the initial exploration of datasets to the application of advanced analytical techniques. By seamlessly integrating into the workflow, Gemma aids in tasks such as data cleaning, preprocessing, descriptive statistics, data visualization, and the interpretation of analysis results. One of Gemma's standout features is its ability to foster a deeper understanding of datasets and analytical outcomes. Through clear explanations, insightful interpretations, and the provision of valuable insights, Gemma empowers data scientists to extract actionable information from their data.
#
# Moreover, Gemma significantly enhances the efficiency of the analysis process by automating repetitive tasks and swiftly responding to user queries. Its robust knowledge representation ensures the delivery of accurate and relevant assistance, guiding users through complex analysis tasks effectively. By practically applying Gemma in this project, we attest to its effectiveness in real-world data science scenarios, where it streamlines workflows and enables data scientists to derive meaningful insights with ease. In essence, Gemma emerges as a valuable ally for data scientists, equipping them with the tools and insights needed to make informed decisions and drive impactful analysis endeavors.

# %% [markdown]
# # Conclusion
# Gemma is a powerful and invaluable tool for data scientists, offering comprehensive support throughout the data analysis process. Its ability to handle various tasks, from data cleaning to advanced analysis techniques, streamlines workflows and enhances efficiency. Gemma's insightful explanations and interpretations facilitate a deeper understanding of datasets, enabling users to derive meaningful insights and make informed decisions. Despite some limitations, Gemma's continuous evolution and improvements promise a bright future, where it will continue to be a cornerstone in the toolkit of data scientists worldwide, driving impactful data-driven discoveries and innovations.
